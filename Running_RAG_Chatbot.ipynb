# %% [markdown]
# # RAG Chatbot

# %% [markdown]
# ## **Install and import libraries**

# %%
# !uv pip install -q transformers==4.52.4
# !uv pip install -q bitsandbytes==0.46.0
# !uv pip install -q accelerate==1.7.0
# !uv pip install -q langchain==0.3.25
# !uv pip install -q langchainhub==0.1.21
# !uv pip install -q langchain-chroma==0.2.4
# !uv pip install -q langchain_experimental==0.3.4
# !uv pip install -q langchain-community==0.3.24
# !uv pip install -q langchain_huggingface==0.2.0
# !uv pip install -q python-dotenv==1.1.0
# !uv pip install -q pypdf
# !uv pip install -q streamlit==1.46.0

# %% [markdown]
# ## **Running RAG Chatbot**

# %% [markdown]
# Instructions for running this file on Google Colab: upload logo.png and every Python script files in the 'src' folder before running.

# %%
# Get password
# !curl https://loca.lt/mytunnelpassword

# %%
# Run streamlit
# !streamlit run rag_chatbot_app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.90.173.244:8501

# %%
# !streamlit run app.py & npx localtunnel --port 8501
